# %% [markdown]
# <a href="https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w04_signal_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-06 — Signal Audit: Do the Flags Hold?
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w04_signal_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Distributions
#
# *Look before deciding: distributions of your key fields. Note the heavy tails.*

# %% [markdown]
# ### 1. Distributions
#
# Before testing any relationships, inspect the distribution of the key variables. Most web analytics metrics such as **clicks, impressions, page views, and traffic** are **heavily right-skewed (heavy-tailed)**, where a small number of pages receive very high traffic while most pages receive relatively little. Because of this, the **mean can be misleading**, and analyses based on raw values may be dominated by a few outliers.
#
# Check each important feature using:
#
# * Histograms or boxplots
# * Summary statistics (`mean`, `median`, `min`, `max`)
# * Missing values and outliers
#
# For heavy-tailed variables, apply **`log1p()`**, use **Spearman correlation**, or compare **grouped medians** instead of relying on raw Pearson correlations. This provides a more reliable view of the underlying patterns before moving on to feature analysis or modeling.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Signal test #1 / #2 / #3 (verdict each)
#
# *Three safe signals, each with a mini-test and a verdict: CONFIRMED / OPPOSITE / MIXED / FALSE.*

# %% [markdown]
# ### 2. Signal Tests
#
# * **Signal #1:** Higher impressions → more clicks. **Verdict:** **CONFIRMED**
# * **Signal #2:** Longer content → higher traffic. **Verdict:** **MIXED**
# * **Signal #3:** Better (lower) average position → higher CTR. **Verdict:** **CONFIRMED**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The flag-linked test
#
# *Pick a signal one of FlyRank's real flags relies on. Does the data support the rule's assumption?*

# %% [markdown]
#  The Flag-Linked Test
#
# I checked whether pages with a negative **trend percentage** are marked as **declining**. The data supports this assumption because pages with decreasing trends are generally labeled as declining.
#
# **Verdict:** **CONFIRMED**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What this means in practice
#
# *Two or three sentences: what a content team should take from this.*

# %% [markdown]
# **What this means in practice**
#
# The content team should focus on pages showing declining trends and update them before traffic drops further. Regularly monitoring performance signals like impressions, CTR, and trend can help prioritize which content needs attention first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
