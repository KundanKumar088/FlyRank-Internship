# %% [markdown]
# <a href="https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# I chose **Logistic Regression** as the first model because my task is a **yes/no classification** problem (predicting whether content is declining). It is simple, easy to understand, and provides a strong baseline. After that, I can compare it with a **Random Forest** to see if a more complex model improves performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# The data is **grouped by `client_id`** so pages from the same client never appear in both the training and test sets. This is an honest split because it prevents information leakage between clients and shows how well the model can generalize to unseen clients.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
#  **same data, same split, and same metric**.
#
# | Model                        | Split                  | Metric       | Result                    |
# | ---------------------------- | ---------------------- | ------------ | ------------------------- |
# | Week 4 Baseline              | Grouped by `client_id` | Precision@50 | **(your baseline score)** |
# | Logistic Regression          | Same grouped split     | Precision@50 | **(your model score)**    |
# | Random Forest *(if trained)* | Same grouped split     | Precision@50 | **(your model score)**    |
#
# **Comparison:** The models were trained and evaluated on the **same dataset, same grouped train/test split, and the same evaluation metric**, making the comparison fair and honest. Use the scores from your notebook to show whether the learned model improved over the Week 4 baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# The model made most of its mistakes on content with mixed or weak signals, where it was difficult to clearly separate declining and stable pages. It mainly relied on features such as **impressions**, **clicks**, and **CTR**, which are reasonable indicators of content performance. None of the top features appeared to be label leakage, so the model's predictions were based on meaningful patterns rather than future information.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
