# %% [markdown]
# <a href="https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Search Ranking & User Engagement
#
# I chose the Search Ranking & User Engagement lane because improving search results has a direct impact on user satisfaction and business performance. When users quickly find relevant results, they are more likely to click, engage, and return to the platform. This problem combines machine learning with real-world decision-making, making it an excellent opportunity to learn how data-driven models can improve search quality while reducing the cost of poor ranking decisions, such as lower click-through rates and decreased user trust.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The goal of this work is to improve the decision of which search results should be ranked highest for a user's query. This decision is made by the search ranking system used by engineers and product teams. A correct ranking helps users find relevant content quickly, increasing clicks and overall satisfaction. A wrong recommendation can push relevant results lower in the rankings, leading to fewer clicks, a poor user experience, reduced user trust, and potential loss of engagement and revenue for the platform.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# After exploring the starter dataset, I found several indicators that make the Search Ranking & User Engagement lane worth investigating. The dataset contains [X] search interactions across [Y] unique queries. The average click-through rate is [Z]%, showing there is room to improve how search results are ranked. These initial findings suggest that better ranking models could increase user engagement and help users find relevant results more efficiently over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will provide decision-support by identifying patterns in search data and evaluating whether a machine learning model can improve the ranking of search results. The findings will be observational and directional, helping engineers and product teams make better ranking decisions based on historical data. However, this project will not prove causation, guarantee future user behavior, or claim to predict or replicate the ranking algorithms of search engines such as Google. Any conclusions will be limited to the available dataset and the performance of the evaluated models.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
