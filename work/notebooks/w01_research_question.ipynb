# %% [markdown]
# <a href="https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/KundanKumar088/FlyRank-Internship-week1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# **My Lane: Classification – Predicting Content Decline**
#
# I chose the **classification** lane because the goal is to identify whether a content page is likely to decline in the near future. This is a practical business problem since SEO analysts and content editors can use these predictions to prioritize which pages to update first. By predicting future decline from historical search performance metrics, the model can help save time, improve search traffic, and support better content management decisions. This lane also provides a clear observed target and measurable evaluation metrics, making it well suited for a machine learning project.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision, Action, and Cost of a Wrong Call**
#
# This project improves the decision of **which content pages should be reviewed and updated first** to prevent future performance decline. The primary users are **SEO analysts and content editors**, who use the model's predictions to prioritize content updates, optimize keywords, and improve page quality. A wrong recommendation can waste time by sending editors to pages that do not need attention (false positives) or, more seriously, miss pages that are actually declining (false negatives), leading to reduced search traffic, lower user engagement, and potential business losses.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# A quick look at the starter dataset shows **30,000 rows** and **44 columns**, providing enough data to train and evaluate a machine learning model. Approximately **X%** of the content items are labeled as declining, making the classification task meaningful. In addition, **Y** pages have `avg_position = 0`, indicating missing ranking data that must be handled carefully during preprocessing. The average CTR is **Z%**, showing variation in content performance and supporting the need for a predictive model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/KundanKumar088/FlyRank-Internship-week1.git
# Out:
# Cloning into 'FlyRank-Internship-week1'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 116 (delta 32), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (116/116), 1.82 MiB | 8.70 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !find FlyRank-Internship-week1 -name "content_refresh_anonymized.csv"
# Out:
# FlyRank-Internship-week1/data/raw/content_refresh_anonymized.csv

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("FlyRank-Internship-week1/data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

# Missing average position (0 means no data)
print("Rows with avg_position == 0:", (df["avg_position"] == 0).sum())

# Average CTR
print("Average CTR (%):", df["ctr"].mean())
# Out:
# Rows: 30000
# Columns: 44
# Rows with avg_position == 0: 1205
# Average CTR (%): 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will provide **observed, directional, and decision-support** insights by identifying content pages that are more likely to experience future performance decline based on historical data. The model is intended to help SEO analysts and content editors prioritize which pages to review and update first. However, it **cannot prove causation**, explain why Google ranks pages the way it does, or accurately predict Google's ranking algorithm. The results should be interpreted as probabilistic recommendations that support human decision-making rather than definitive predictions or causal evidence.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
